# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #**Pre-Processing**#

# %%
#import dataset
assessment = pd.read_csv("/content/assessments.csv")
assessment.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
#mengecek missing value
print(assessment.isnull().values.any())
# Out:
# True

# %%
#drop missing value
assessment.dropna(axis=0, inplace=True)

# %%
#mengecek data duplikat
assessment.duplicated().values.any()
# Out:
# False

# %%
#Mengambil nilai unik
assessment['code_module'].unique()
# Out:
# array(['AAA', 'BBB', 'CCC', 'DDD', 'EEE', 'FFF', 'GGG'], dtype=object)

# %%
assessment['assessment_type'].unique()
# Out:
# array(['TMA', 'CMA', 'Exam'], dtype=object)

# %%
assessment.describe()
# Out:
#        id_assessment        date      weight
# count     195.000000  195.000000  195.000000
# mean    26851.056410  145.005128   16.410256
# std      9830.992674   76.001119   24.505488
# min      1752.000000   12.000000    0.000000
# 25%     24282.500000   71.000000    0.000000
# 50%     25367.000000  152.000000   10.000000
# 75%     34892.500000  222.000000   20.000000
# max     37444.000000  261.000000  100.000000

# %%
assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        195 non-null    object
#  1   code_presentation  195 non-null    object
#  2   id_assessment      195 non-null    int64
#  3   assessment_type    195 non-null    object
#  4   date               195 non-null    float64
#  5   weight             195 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 10.7+ KB

# %%
#encoding
labelencoder = LabelEncoder()

assessment['code_module'] = labelencoder.fit_transform(assessment['code_module'])
assessment['code_presentation'] = labelencoder.fit_transform(assessment['code_presentation'])
assessment['assessment_type'] = labelencoder.fit_transform(assessment['assessment_type'])
assessment['date'] = labelencoder.fit_transform(assessment['date'])
assessment['weight'] = labelencoder.fit_transform(assessment['weight'])

# %%
courses = pd.read_csv("/content/courses.csv")

# %%
courses.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
print(courses.isnull().values.any())
# Out:
# False

# %%
courses.duplicated().values.any()
# Out:
# False

# %%
courses.describe()
# Out:
#        module_presentation_length
# count                   22.000000
# mean                   255.545455
# std                     13.654677
# min                    234.000000
# 25%                    241.000000
# 50%                    261.500000
# 75%                    268.000000
# max                    269.000000

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes

# %%
courses['code_module'] = labelencoder.fit_transform(courses['code_module'])
courses['code_presentation'] = labelencoder.fit_transform(courses['code_presentation'])

# %%
student_assessment = pd.read_csv("/content/studentAssessment.csv")

# %%
student_assessment.head()
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %%
print(student_assessment.isnull().values.any())
# Out:
# True

# %%
student_assessment.dropna(axis=0, inplace=True)

# %%
student_assessment.duplicated().values.any()
# Out:
# False

# %%
student_assessment.describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173739.000000  1.737390e+05   173739.000000  173739.000000
# mean    26555.615826  7.052474e+05      116.020226       0.010982
# std      8829.999907  5.524822e+05       71.479612       0.104218
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044660e+05       51.000000       0.000000
# 50%     25359.000000  5.852220e+05      116.000000       0.000000
# 75%     34883.000000  6.345000e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %%
student_assessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173739 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173739 non-null  int64
#  1   id_student      173739 non-null  int64
#  2   date_submitted  173739 non-null  int64
#  3   is_banked       173739 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 8.0 MB

# %%
student_assessment['score'] = labelencoder.fit_transform(student_assessment['score'])

# %%
student_registration = pd.read_csv("/content/studentRegistration.csv")

# %%
student_registration.head()
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
print(student_registration.isnull().values.any())
# Out:
# True

# %%
student_registration.dropna(axis=0, inplace=True)

# %%
student_registration.duplicated().values.any()
# Out:
# False

# %%
student_registration.describe()
# Out:
#          id_student  date_registration  date_unregistration
# count  1.003300e+04       10033.000000         10033.000000
# mean   7.086265e+05         -78.521379            50.276189
# std    5.479573e+05          53.168107            82.028804
# min    3.733000e+03        -322.000000          -317.000000
# 25%    5.099400e+05        -115.000000            -1.000000
# 50%    5.916500e+05         -67.000000            28.000000
# 75%    6.481300e+05         -32.000000           109.000000
# max    2.698591e+06         167.000000           444.000000

# %%
student_registration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10033 entries, 2 to 32591
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          10033 non-null  object
#  1   code_presentation    10033 non-null  object
#  2   id_student           10033 non-null  int64
#  3   date_registration    10033 non-null  float64
#  4   date_unregistration  10033 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 470.3+ KB

# %%
student_registration['code_module'] = labelencoder.fit_transform(student_registration['code_module'])
student_registration['code_presentation'] = labelencoder.fit_transform(student_registration['code_presentation'])
student_registration['date_registration'] = labelencoder.fit_transform(student_registration['date_registration'])
student_registration['date_unregistration'] = labelencoder.fit_transform(student_registration['date_unregistration'])

# %%
student_info = pd.read_csv("/content/studentInfo.csv")

# %%
student_info.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
print(student_info.isnull().values.any())
# Out:
# True

# %%
student_info.dropna(axis=0, inplace=True)

# %%
student_info.duplicated().values.any()
# Out:
# False

# %%
student_info.describe()
# Out:
#          id_student  num_of_prev_attempts  studied_credits
# count  3.148200e+04          31482.000000     31482.000000
# mean   7.069493e+05              0.164507        79.767804
# std    5.505441e+05              0.482633        41.049455
# min    3.733000e+03              0.000000        30.000000
# 25%    5.076005e+05              0.000000        60.000000
# 50%    5.898190e+05              0.000000        60.000000
# 75%    6.441622e+05              0.000000       120.000000
# max    2.716795e+06              6.000000       655.000000

# %%
student_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31482 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           31482 non-null  object
#  1   code_presentation     31482 non-null  object
#  2   id_student            31482 non-null  int64
#  3   gender                31482 non-null  object
#  4   region                31482 non-null  object
#  5   highest_education     31482 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              31482 non-null  object
#  8   num_of_prev_attempts  31482 non-null  int64
#  9   studied_credits       31482 non-null  int64
#  10  disability            31482 non-null  object
#  11  final_result          31482 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.1+ MB

# %%
student_info['code_module'] = labelencoder.fit_transform(student_info['code_module'])
student_info['code_presentation'] = labelencoder.fit_transform(student_info['code_presentation'])
student_info['gender'] = labelencoder.fit_transform(student_info['gender'])
student_info['region'] = labelencoder.fit_transform(student_info['region'])
student_info['highest_education'] = labelencoder.fit_transform(student_info['highest_education'])
student_info['imd_band'] = labelencoder.fit_transform(student_info['imd_band'])
student_info['age_band'] = labelencoder.fit_transform(student_info['age_band'])
student_info['disability'] = labelencoder.fit_transform(student_info['disability'])
student_info['final_result'] = labelencoder.fit_transform(student_info['final_result'])

# %%
student_vle = pd.read_csv("/content/studentVle.csv")

# %%
student_vle.head()
# Out:
#   code_module code_presentation  id_student   id_site  date  sum_click
# 0         AAA             2013J       28400  546652.0 -10.0        4.0
# 1         AAA             2013J       28400  546652.0 -10.0        1.0
# 2         AAA             2013J       28400  546652.0 -10.0        1.0
# 3         AAA             2013J       28400  546614.0 -10.0       11.0
# 4         AAA             2013J       28400  546714.0 -10.0        1.0

# %%
print(student_vle.isnull().values.any())
# Out:
# True

# %%
student_vle.dropna(axis=0, inplace=True)

# %%
student_vle.duplicated().values.any()
# Out:
# True

# %%
student_vle = student_vle.drop_duplicates(keep=False)

# %%
student_vle.describe()
# Out:
#          id_student        id_site           date      sum_click
# count  1.142040e+05  114204.000000  114204.000000  114204.000000
# mean   1.082809e+06  546713.041049      59.365644       3.844874
# std    9.918596e+05     104.798115      50.191105       5.928782
# min    1.139100e+04  546614.000000     -10.000000       1.000000
# 25%    2.380070e+05  546650.000000      15.000000       1.000000
# 50%    4.299580e+05  546667.000000      49.000000       2.000000
# 75%    2.153153e+06  546734.000000     106.000000       5.000000
# max    2.698257e+06  547067.000000     157.000000    1326.000000

# %%
student_vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114204 entries, 0 to 123009
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   code_module        114204 non-null  object
#  1   code_presentation  114204 non-null  object
#  2   id_student         114204 non-null  int64
#  3   id_site            114204 non-null  float64
#  4   date               114204 non-null  float64
#  5   sum_click          114204 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 6.1+ MB

# %%
student_vle['code_module'] = labelencoder.fit_transform(student_vle['code_module'])
student_vle['code_presentation'] = labelencoder.fit_transform(student_vle['code_presentation'])
student_vle['date'] = labelencoder.fit_transform(student_vle['date'])
student_vle['sum_click'] = labelencoder.fit_transform(student_vle['sum_click'])

# %%
vle = pd.read_csv("/content/vle.csv")

# %%
vle.head()
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
print(vle.isnull().sum())
# Out:
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64

# %%
vle = vle.drop(['week_from', 'week_to'], axis = 1)

# %%
vle.duplicated().values.any()
# Out:
# False

# %%
vle.describe()
# Out:
#             id_site
# count  6.364000e+03
# mean   7.260991e+05
# std    1.283151e+05
# min    5.267210e+05
# 25%    6.615928e+05
# 50%    7.300965e+05
# 75%    8.140162e+05
# max    1.077905e+06

# %%
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 199.0+ KB

# %%
vle['code_module'] = labelencoder.fit_transform(vle['code_module'])
vle['code_presentation'] = labelencoder.fit_transform(vle['code_presentation'])
vle['activity_type'] = labelencoder.fit_transform(vle['activity_type'])

# %%
def stacked_plot(data, column_one, column_two, agg_column, plot_size=(10, 5)):
    pal     = sns.color_palette("colorblind")
    grouped = data.groupby([column_one, column_two])[agg_column].count()
    grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
    grouped = grouped.unstack(column_two).fillna(0)
    print(grouped)
    unique_list = list(data[column_two].unique())
    grouped[unique_list].plot(kind='bar', stacked=True, color=pal, figsize=plot_size)

# %%
#Menggabungkan tabel student_assessment dengan tabel assessment
student_assessment_merge_assessment = student_assessment.merge(assessment,
                                                                     on = ['id_assessment'], how='left' )

# %%
student_assessment_merge_assessment.dtypes
# Out:
# id_assessment          int64
# id_student             int64
# date_submitted         int64
# is_banked              int64
# score                  int64
# code_module          float64
# code_presentation    float64
# assessment_type      float64
# date                 float64
# weight               float64
# dtype: object

# %%
student_assessment_merge_assessment['Late_submission'] = student_assessment_merge_assessment.apply(lambda row: '0' if row['date_submitted'] > row['date'] else '1', axis=1)

# %%
print('Percentage of Late Submissions : ')
print((len(student_assessment_merge_assessment[student_assessment_merge_assessment['Late_submission']=='0'])/len(student_assessment_merge_assessment)*100))
# Out:
# Percentage of Late Submissions :
# 93.82119155745113

# %%
stacked_plot(student_assessment_merge_assessment, 'assessment_type', 'Late_submission', 'id_student', plot_size=(10, 7))
# Out:
# <ipython-input-153-e7a631b39987>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
# Late_submission           0         1
# assessment_type
# 0.0               91.065833  8.934167
# 1.0              100.000000  0.000000
# 2.0               98.403102  1.596898

# %%
stacked_plot(student_assessment_merge_assessment, 'code_module', 'Late_submission', 'id_student', plot_size=(12, 8))
# Out:
# <ipython-input-153-e7a631b39987>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
# Late_submission          0          1
# code_module
# 0.0              98.664971   1.335029
# 1.0              98.515554   1.484446
# 2.0              99.165393   0.834607
# 3.0              97.974217   2.025783
# 4.0              99.492772   0.507228
# 5.0              88.345597  11.654403
# 6.0              99.868551   0.131449

# %%
student_assessment_merge_assessment['Code_Category'] = ['Social_Science' if student_assessment_merge_assessment['code_module'].iloc[i] in ['AAA', 'BBB', 'GGG']
                                                        else 'STEM' for i in range(len(student_assessment_merge_assessment))]

# %%
stacked_plot(student_assessment_merge_assessment, 'Code_Category', 'Late_submission', 'id_student', plot_size=(8, 7))
# Out:
# <ipython-input-153-e7a631b39987>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
# Late_submission          0         1
# Code_Category
# STEM             93.821192  6.178808

# %%
student_assessment_merge_assessment['Result'] = ['Fail' if int(student_assessment_merge_assessment['score'].iloc[i]) < 40
                                                        else 'Pass' for i in range(len(student_assessment_merge_assessment))]

# %%
stacked_plot(student_assessment_merge_assessment, 'Code_Category', 'Result', 'id_student', plot_size=(10, 7))
# Out:
# <ipython-input-153-e7a631b39987>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
# Result             Fail       Pass
# Code_Category
# STEM           4.361715  95.638285

# %%
stacked_plot(student_assessment_merge_assessment, 'code_module', 'Result', 'id_student', plot_size=(15, 8))
# Out:
# <ipython-input-153-e7a631b39987>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   grouped = grouped.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
# Result           Fail       Pass
# code_module
# 0.0          2.860776  97.139224
# 1.0          3.306266  96.693734
# 2.0          8.980839  91.019161
# 3.0          8.970367  91.029633
# 4.0          1.775298  98.224702
# 5.0          1.975570  98.024430
# 6.0          1.958593  98.041407
